# %% [markdown]
# # Exercise Set I - Python

# %% [markdown]
# ### Exercise 1
#
# Define the following object types. Moreover, provide one example of each.
#
# (a) Dictionaries
#
# (b) Lists
#
# (c) Floating-point numbers
#
# (d) Tuples
#
#
#
#
#
# ### Exercise 2
#
# Indicate the data type of each of the following values. Then use the `type()` function to verify your assertion.
#
# (a) 'Social Insurance'
#
# (b) 123.0
#
# (c) "123"
#
# (d) '123'
#
# (e) 123
#
#
#
#
#
#
#
# ### Exercise 3
#
# Indicate the data type of each of the following results of operations. Then use the `type()` function to verify your assertion. Do they all work?
#
# (a) 4 / 2.0
#
# (b) 5 // 2.0
#
# (c) "Actuarial" + "Data Science"
#
# (d) 2 + 3.0
#
# (e) 65 + 3
#
# (f) "30" + 3
#
#
#
#
#
#
#
# ### Exercise 4
#
# Which of the following variable names are acceptable and which are not? If one of these names is unacceptable, explain why.
#
# (a) COUNTRY
#
# (b) lambda
#
# (c) loss 1
#
# (d) loss_1
#
# (e) 1st_loss
#
# (f) PolicyID
#
# (g) zipcode
#
# (h) _carmodel
#
#
#
#
#
#
#
# ### Exercise 5
#
# Run the following lines of code and indicate the final value of `x`. Can you explain in more detail what each line of code does?
#
# - `x = 22`
#
# - `x-=1`
#
# - `x//=4`
#
# - `x*=3`
#
# - `x+=7`
#
#
#
#
#
# ### Exercise 6
#
# As we discussed in the lecture, in Python, the data type of a variable is dynamically inferred. Run the following statement: `z = 8`. Then, use the `type()` function to check its data type. What data type is it? Now, increment `z` by `2`, using the `+=` operator, then check its data type again. Did it change? What data type is it now? Increment `z` by `2.0` (again using the `+=` operator), then check its data type again. Did it change? What data type is it now?
#
#
#
#
#
#
# ### Exercise 7
#
# Using Python, calculate the present value of the following cashflows using a constant force of interest of $δ = 0.07\%$ per month:
#
# (a) CHF 20 in 7 months, followed by
#
# (b) CHF 45 in 4 years.
#
#
#
#
#
#
#
# ### Exercise 8
#
# Define the variables `a = estimator`, `b = biased` and `c = ho`. What is the result of each statement? Which do not work, and why?
#
# (a) b + " " + a
#
# (b) a + " " + b
#
# (c) c * 7
#
# (d)  a * c
#
# (e) a + 8
#
# (f) b + "8"
#
#
#
#
#
#
#
# ### Exercise 9
#
# Explain why the following error occurs:
#
# ![](Images/run-time-error.png)
#
#
#
#
#
# ### Exercise 10
#
# Select a meaningful variable name that represents the following situations:
#
# (a) The total number of claims incurred by an insurance company
#
# (b) The total losses incurred by an insurance company
#
# (c) The age of a policyholder
#
# (d) The Policy ID of an insurance card
#
#
#
#
#
# ## Summary
#
# These exercises, albeit very basic, covered the essential Python fundamentals for data science and actuarial work:
#
# 1. **Data Types**: Dictionaries, lists, tuples, and floats for different data structures
# 2. **Type System**: Dynamic typing, type coercion, and error handling
# 3. **Variables**: Naming conventions and Python syntax rules
# 4. **Operations**: Arithmetic operators and string manipulation
# 5. **Applications**: Present value calculations and actuarial problem-solving
#
# These fundamentals prepare you for NumPy arrays, Pandas DataFrames, and data visualization.
